# %% [raw]
# ---
# output-file: cli.html
# title: Generate HEALPix sidecar
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(to_geoparquet_cli)
# Out:
# ---
#
# ### to_geoparquet_cli
#
# >      to_geoparquet_cli ()
#
# *CLI entry point for healpyxel_to_geoparquet command.*

# %%
#| echo: false
#| output: asis
show_doc(finalize_cli)
# Out:
# ---
#
# ### finalize_cli
#
# >      finalize_cli ()
#
# *CLI entry point for healpix_finalize command.*

# %%
#| echo: false
#| output: asis
show_doc(accumulator_cli)
# Out:
# ---
#
# ### accumulator_cli
#
# >      accumulator_cli ()
#
# *CLI entry point for healpix_accumulator command.*

# %%
#| echo: false
#| output: asis
show_doc(aggregate_cli)
# Out:
# ---
#
# ### aggregate_cli
#
# >      aggregate_cli ()
#
# *CLI entry point for healpix_aggregate command.*

# %%
#| echo: false
#| output: asis
show_doc(sidecar_cli)
# Out:
# ---
#
# ### sidecar_cli
#
# >      sidecar_cli (argv=None)
#
# *CLI entry point for healpyxel_sidecar.
#
# Thin wrapper around sidecar.main() that handles argparse setup.
# All argument validation and parsing happens here; core logic stays in sidecar.main().*

# %%
#| echo: false
#| output: asis
show_doc(validate_lon_lat_columns)
# Out:
# ---
#
# ### validate_lon_lat_columns
#
# >      validate_lon_lat_columns (df, lon_col, lat_col, mode, input_file)
#
# *Validate or auto-detect lon/lat columns. Fail fast with context.
# Returns (lon_col, lat_col) or raises ValueError.*

# %%
#| echo: false
#| output: asis
show_doc(cache_cli)
# Out:
# ---
#
# ### cache_cli
#
# >      cache_cli ()
#
# *CLI entry point for healpyxel-cache command.*

# %% [markdown]
# ## CLI Entry Points
#
# These functions are called when using the command-line tools:
# - `healpix_sidecar` → `sidecar_cli()`
# - `healpix_aggregate` → `aggregate_cli()`
# - `healpix_accumulator` → `accumulator_cli()`
# - `healpix_finalize` → `finalize_cli()`
# - `healpyxel_to_geoparquet` → `to_geoparquet_cli()`
# - `healpyxel-cache` → `cache_cli()`
